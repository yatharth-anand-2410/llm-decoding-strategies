# %% [markdown]
# # 14. Lookahead Decoding
# Parallel multi-n-gram generation via Jacobi Iteration (no draft model). Breaks autoregressive bottleneck directly.

# %%
def lookahead_step(model, context, n_grams):
    # Pseudo-code for verifying parallel n-gram branches
    pass

# %% [markdown]
# ### Experiment: Speed vs Speculative Decoding
# Prompt: `" land humans on the Moon"`.
